# %%
# Import dependencies
import pandas as pd
import numpy as np
from citipy import citipy
import sys
sys.path.append('..')
from config import weather_api_key
import requests

# %%
# Create set of 2,000 latitudes and longitudes
lats = np.random.uniform(-90, 90, 2000)
lngs = np.random.uniform(-180, 180, 2000)
# Zip both lists and extract to a list of coordinates
coords = list(zip(lats,lngs))

# %%
# Initialize cities list
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coord in coords:
    city = citipy.nearest_city(coord[0], coord[1]).city_name
    country = citipy.nearest_city(coord[0], coord[1]).country_code
    
    # If the city is unique, then we will add it to the cities list.
    if (city,country) not in cities:
        cities.append((city,country))

# %%
# Check the number of cities
len(cities)
# Out:
# 749

# %%
# base url for OWM calls
base_url = "http://api.openweathermap.org/data/2.5/weather"

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count+=1
        record_count = 1
    # Create parameters.
    params = {"q": city, "units": "Imperial", "APPID": weather_api_key}
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of the Set {set_count} | {city[0]}")
    
    # Add 1 to the record count.
    record_count+=1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(base_url, params=params).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_desc = str(city_weather["weather"][0]["description"])
        # Append the city information into city_data list.
        city_data.append({
            "City": city[0].title(),
            "Lat": city_lat,
            "Lng": city_lng,
            "Max Temp": city_max_temp,
            "Humidity": city_humidity,
            "Cloudiness": city_clouds,
            "Wind Speed": city_wind,
            "Country": city_country,
            "Current Description": city_weather_desc})
    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of the Set 1 | itaituba
# Processing Record 2 of the Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 3 of the Set 1 | bluff
# Processing Record 4 of the Set 1 | rawson
# Processing Record 5 of the Set 1 | geraldton
# Processing Record 6 of the Set 1 | aklavik
# Processing Record 7 of the Set 1 | albany
# Processing Record 8 of the Set 1 | erenhot
# Processing Record 9 of the Set 1 | gat
# Processing Record 10 of the Set 1 | poum
# Processing Record 11 of the Set 1 | babanusah
# Processing Record 12 of the Set 1 | fairbanks
# Processing Record 13 of the Set 1 | port elizabeth
# Processing Record 14 of the Set 1 | jackson
# Processing Record 15 of the Set 1 | butaritari
# Processing Record 16 of the Set 1 | kununurra
# Processing Record 17 of the Set 1 | busselton
# Processing Record 18 of the Set 1 | hermanus
# Processing Record 19 of the Set 1 | saint-philippe
# Processing Record 20 of the Set 1 | saint-francois
# Processing Record 21 of the Set 1 | gannan
# Processing Record 22 of the Set 1 | rikitea
# Processing Record 23 of the Set 1 | ushuaia
# Processing Record 24 of the Set 1 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 25 of the Set 1 | snyder
# Processing Record 26 of the Set 1 | luderitz
# Processing Record 27 of the Set 1 | eureka
# Processing Record 28 of the Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 29 of the Set 1 | tawkar
# City not found. Skipping...
# Processing Record 30 of the Set 1 | punta arenas
# Processing Record 31 of the Set 1 | codrington
# Processing Record 32 of the Set 1 | ponta do sol
# Processing Record 33 of the Set 1 | cururupu
# Processing Record 34 of the Set 1 | saleaula
# City not found. Skipping...
# Processing Record 35 of the Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 36 of the Set 1 | new norfolk
# Processing Record 37 of the Set 1 | kapaa
# Processing Record 38 of the Set 1 | east london
# Processing Record 39 of the Set 1 | hilo
# Processing Record 40 of the Set 1 | cabo san lucas
# Processing Record 41 of the Set 1 | yellowknife
# Processing Record 42 of the Set 1 | batagay
# City not found. Skipping...
# Processing Record 43 of the Set 1 | jiazi
# Processing Record 44 of the Set 1 | bethel
# Processing Record 45 of the Set 1 | nalut
# Processing Record 46 of the Set 1 | dikson
# City not found. Skipping...
# Processing Record 47 of the Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 48 of the Set 1 | sioux lookout
# Processing Record 49 of the Set 1 | katsuura
# Processing Record 50 of the Set 1 | cape town
# Processing Record 1 of the Set 2 | bratsk
# City not found. Skipping...
# Processing Record 2 of the Set 2 | avarua
# Processing Record 3 of the Set 2 | punta de bombon
# Processing Record 4 of the Set 2 | hithadhoo
# Processing Record 5 of the Set 2 | chuy
# Processing Record 6 of the Set 2 | kahului
# Processing Record 7 of the Set 2 | provideniya
# City not found. Skipping...
# Processing Record 8 of the Set 2 | ribeira grande
# Processing Record 9 of the Set 2 | karauzyak
# City not found. Skipping...
# Processing Record 10 of the Set 2 | fortuna
# Processing Record 11 of the Set 2 | longlac
# Processing Record 12 of the Set 2 | atuona
# Processing Record 13 of the Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 14 of the Set 2 | georgetown
# Processing Record 15 of the Set 2 | puerto narino
# Processing Record 16 of the Set 2 | pacific grove
# Processing Record 17 of the Set 2 | manaus
# Processing Record 18 of the Set 2 | nuevitas
# Processing Record 19 of the Set 2 | guerrero negro
# Processing Record 20 of the Set 2 | talaya
# City not found. Skipping...
# Processing Record 21 of the Set 2 | otane
# Processing Record 22 of the Set 2 | lobito
# Processing Record 23 of the Set 2 | port alfred
# Processing Record 24 of the Set 2 | bengkulu
# Processing Record 25 of the Set 2 | hobart
# Processing Record 26 of the Set 2 | sosnovo-ozerskoye
# City not found. Skipping...
# Processing Record 27 of the Set 2 | kodiak
# Processing Record 28 of the Set 2 | mehamn
# Processing Record 29 of the Set 2 | bonthe
# Processing Record 30 of the Set 2 | limburg
# Processing Record 31 of the Set 2 | skjervoy
# Processing Record 32 of the Set 2 | muktagachha
# City not found. Skipping...
# Processing Record 33 of the Set 2 | le port
# Processing Record 34 of the Set 2 | rantepao
# Processing Record 35 of the Set 2 | hokitika
# Processing Record 36 of the Set 2 | arraial do cabo
# Processing Record 37 of the Set 2 | san patricio
# Processing Record 38 of the Set 2 | airai
# Processing Record 39 of the Set 2 | ostrovnoy
# City not found. Skipping...
# Processing Record 40 of the Set 2 | buchanan
# Processing Record 41 of the Set 2 | sitka
# Processing Record 42 of the Set 2 | unity
# Processing Record 43 of the Set 2 | jamestown
# Processing Record 44 of the Set 2 | bandar-e anzali
# Processing Record 45 of the Set 2 | victoria
# Processing Record 46 of the Set 2 | port macquarie
# Processing Record 47 of the Set 2 | itarema
# Processing Record 48 of the Set 2 | rehoboth
# Processing Record 49 of the Set 2 | isangel
# Processing Record 50 of the Set 2 | tasiilaq
# Processing Record 1 of the Set 3 | chupa
# City not found. Skipping...
# Processing Record 2 of the Set 3 | khani
# City not found. Skipping...
# Processing Record 3 of the Set 3 | volnovakha
# Processing Record 4 of the Set 3 | tiksi
# City not found. Skipping...
# Processing Record 5 of the Set 3 | tura
# City not found. Skipping...
# Processing Record 6 of the Set 3 | sola
# Processing Record 7 of the Set 3 | vostok
# City not found. Skipping...
# Processing Record 8 of the Set 3 | puerto ayora
# Processing Record 9 of the Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 10 of the Set 3 | najran
# Processing Record 11 of the Set 3 | severo-kurilsk
# City not found. Skipping...
# Processing Record 12 of the Set 3 | pemangkat
# Processing Record 13 of the Set 3 | vaini
# Processing Record 14 of the Set 3 | barra do garcas
# Processing Record 15 of the Set 3 | husavik
# Processing Record 16 of the Set 3 | rovaniemi
# Processing Record 17 of the Set 3 | alabaster
# Processing Record 18 of the Set 3 | savalou
# Processing Record 19 of the Set 3 | valparaiso
# Processing Record 20 of the Set 3 | upington
# Processing Record 21 of the Set 3 | marsabit
# Processing Record 22 of the Set 3 | srednekolymsk
# City not found. Skipping...
# Processing Record 23 of the Set 3 | longyearbyen
# City not found. Skipping...
# Processing Record 24 of the Set 3 | umzimvubu
# Processing Record 25 of the Set 3 | winneba
# Processing Record 26 of the Set 3 | te anau
# Processing Record 27 of the Set 3 | castro
# Processing Record 28 of the Set 3 | ekhabi
# City not found. Skipping...
# Processing Record 29 of the Set 3 | rexburg
# Processing Record 30 of the Set 3 | lebu
# Processing Record 31 of the Set 3 | hirson
# Processing Record 32 of the Set 3 | anaco
# Processing Record 33 of the Set 3 | carnarvon
# Processing Record 34 of the Set 3 | richards bay
# Processing Record 35 of the Set 3 | huaidian
# Processing Record 36 of the Set 3 | amderma
# City not found. Skipping...
# Processing Record 37 of the Set 3 | zhezkazgan
# Processing Record 38 of the Set 3 | lagoa
# Processing Record 39 of the Set 3 | margate
# Processing Record 40 of the Set 3 | bambous virieux
# Processing Record 41 of the Set 3 | torbay
# Processing Record 42 of the Set 3 | mar del plata
# Processing Record 43 of the Set 3 | nikolskoye
# City not found. Skipping...
# Processing Record 44 of the Set 3 | hualmay
# Processing Record 45 of the Set 3 | tuktoyaktuk
# Processing Record 46 of the Set 3 | vikulovo
# City not found. Skipping...
# Processing Record 47 of the Set 3 | arman
# City not found. Skipping...
# Processing Record 48 of the Set 3 | amahai
# Processing Record 49 of the Set 3 | guajara-mirim
# Processing Record 50 of the Set 3 | werda
# Processing Record 1 of the Set 4 | macaboboni
# City not found. Skipping...
# Processing Record 2 of the Set 4 | aripuana
# Processing Record 3 of the Set 4 | qaanaaq
# Processing Record 4 of the Set 4 | comodoro rivadavia
# Processing Record 5 of the Set 4 | illoqqortoormiut
# Processing Record 6 of the Set 4 | bredasdorp
# Processing Record 7 of the Set 4 | mataura
# Processing Record 8 of the Set 4 | thompson
# Processing Record 9 of the Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 10 of the Set 4 | kitimat
# Processing Record 11 of the Set 4 | okhotsk
# City not found. Skipping...
# Processing Record 12 of the Set 4 | butwal
# Processing Record 13 of the Set 4 | lakes entrance
# Processing Record 14 of the Set 4 | ancud
# Processing Record 15 of the Set 4 | port-gentil
# Processing Record 16 of the Set 4 | borovskoy
# Processing Record 17 of the Set 4 | ponta delgada
# Processing Record 18 of the Set 4 | zhuzhou
# Processing Record 19 of the Set 4 | alice springs
# Processing Record 20 of the Set 4 | esperance
# Processing Record 21 of the Set 4 | cherskiy
# City not found. Skipping...
# Processing Record 22 of the Set 4 | tommot
# City not found. Skipping...
# Processing Record 23 of the Set 4 | san quintin
# Processing Record 24 of the Set 4 | wanlaweyn
# Processing Record 25 of the Set 4 | morehead
# Processing Record 26 of the Set 4 | barrow
# Processing Record 27 of the Set 4 | mareeba
# Processing Record 28 of the Set 4 | ust-nera
# City not found. Skipping...
# Processing Record 29 of the Set 4 | raton
# Processing Record 30 of the Set 4 | pevek
# City not found. Skipping...
# Processing Record 31 of the Set 4 | roma
# Processing Record 32 of the Set 4 | buin
# Processing Record 33 of the Set 4 | mahanoro
# City not found. Skipping...
# Processing Record 34 of the Set 4 | marawi
# City not found. Skipping...
# Processing Record 35 of the Set 4 | marcona
# Processing Record 36 of the Set 4 | pangnirtung
# Processing Record 37 of the Set 4 | san francisco
# Processing Record 38 of the Set 4 | bonavista
# Processing Record 39 of the Set 4 | stokmarknes
# Processing Record 40 of the Set 4 | chokurdakh
# City not found. Skipping...
# Processing Record 41 of the Set 4 | terrace
# Processing Record 42 of the Set 4 | lodwar
# Processing Record 43 of the Set 4 | nizamabad
# Processing Record 44 of the Set 4 | port lincoln
# Processing Record 45 of the Set 4 | mount gambier
# Processing Record 46 of the Set 4 | novikovo
# City not found. Skipping...
# Processing Record 47 of the Set 4 | svetlyy
# City not found. Skipping...
# Processing Record 48 of the Set 4 | tunduru
# City not found. Skipping...
# Processing Record 49 of the Set 4 | wahran
# City not found. Skipping...
# Processing Record 50 of the Set 4 | kegayli
# City not found. Skipping...
# Processing Record 1 of the Set 5 | khatanga
# City not found. Skipping...
# Processing Record 2 of the Set 5 | klaksvik
# Processing Record 3 of the Set 5 | cozumel
# Processing Record 4 of the Set 5 | el balsamo
# Processing Record 5 of the Set 5 | huatulco
# Processing Record 6 of the Set 5 | komsomolskiy
# City not found. Skipping...
# Processing Record 7 of the Set 5 | dergachi
# City not found. Skipping...
# Processing Record 8 of the Set 5 | sturgis
# Processing Record 9 of the Set 5 | kruisfontein
# Processing Record 10 of the Set 5 | kaitangata
# Processing Record 11 of the Set 5 | lavrentiya
# City not found. Skipping...
# Processing Record 12 of the Set 5 | quang ngai
# Processing Record 13 of the Set 5 | santa cruz de la palma
# Processing Record 14 of the Set 5 | kuytun
# Processing Record 15 of the Set 5 | santiago del estero
# Processing Record 16 of the Set 5 | padang
# Processing Record 17 of the Set 5 | champerico
# Processing Record 18 of the Set 5 | baykalovo
# City not found. Skipping...
# Processing Record 19 of the Set 5 | bac lieu
# Processing Record 20 of the Set 5 | port blair
# Processing Record 21 of the Set 5 | ilhabela
# Processing Record 22 of the Set 5 | chernyshevskiy
# City not found. Skipping...
# Processing Record 23 of the Set 5 | praia da vitoria
# Processing Record 24 of the Set 5 | magadan
# City not found. Skipping...
# Processing Record 25 of the Set 5 | fort nelson
# Processing Record 26 of the Set 5 | khandyga
# City not found. Skipping...
# Processing Record 27 of the Set 5 | saldanha
# Processing Record 28 of the Set 5 | lasa
# Processing Record 29 of the Set 5 | talnakh
# City not found. Skipping...
# Processing Record 30 of the Set 5 | maraba
# Processing Record 31 of the Set 5 | araouane
# Processing Record 32 of the Set 5 | pisco
# Processing Record 33 of the Set 5 | polson
# Processing Record 34 of the Set 5 | deer lake
# Processing Record 35 of the Set 5 | awjilah
# Processing Record 36 of the Set 5 | vao
# Processing Record 37 of the Set 5 | sao filipe
# Processing Record 38 of the Set 5 | souillac
# Processing Record 39 of the Set 5 | luis correia
# Processing Record 40 of the Set 5 | katangli
# City not found. Skipping...
# Processing Record 41 of the Set 5 | hobyo
# Processing Record 42 of the Set 5 | kabare
# Processing Record 43 of the Set 5 | roald
# Processing Record 44 of the Set 5 | nyurba
# City not found. Skipping...
# Processing Record 45 of the Set 5 | carson city
# Processing Record 46 of the Set 5 | beringovskiy
# City not found. Skipping...
# Processing Record 47 of the Set 5 | balkanabat
# Processing Record 48 of the Set 5 | saint-leu
# Processing Record 49 of the Set 5 | saint george
# Processing Record 50 of the Set 5 | necochea
# Processing Record 1 of the Set 6 | bambanglipuro
# Processing Record 2 of the Set 6 | mahebourg
# Processing Record 3 of the Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 4 of the Set 6 | riachao das neves
# Processing Record 5 of the Set 6 | orlik
# City not found. Skipping...
# Processing Record 6 of the Set 6 | la rioja
# Processing Record 7 of the Set 6 | toftir
# Processing Record 8 of the Set 6 | upernavik
# Processing Record 9 of the Set 6 | tarko-sale
# City not found. Skipping...
# Processing Record 10 of the Set 6 | mocambique
# City not found. Skipping...
# Processing Record 11 of the Set 6 | tessalit
# Processing Record 12 of the Set 6 | paranaiba
# Processing Record 13 of the Set 6 | moerai
# Processing Record 14 of the Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 15 of the Set 6 | leningradskiy
# City not found. Skipping...
# Processing Record 16 of the Set 6 | viedma
# Processing Record 17 of the Set 6 | puri
# Processing Record 18 of the Set 6 | saskylakh
# City not found. Skipping...
# Processing Record 19 of the Set 6 | anadyr
# City not found. Skipping...
# Processing Record 20 of the Set 6 | meyungs
# Processing Record 21 of the Set 6 | ternate
# Processing Record 22 of the Set 6 | unjha
# Processing Record 23 of the Set 6 | copiapo
# Processing Record 24 of the Set 6 | rapid valley
# Processing Record 25 of the Set 6 | caravelas
# Processing Record 26 of the Set 6 | lima
# Processing Record 27 of the Set 6 | hihifo
# Processing Record 28 of the Set 6 | batagay-alyta
# City not found. Skipping...
# Processing Record 29 of the Set 6 | saint-augustin
# Processing Record 30 of the Set 6 | armacao dos buzios
# Processing Record 31 of the Set 6 | azanka
# City not found. Skipping...
# Processing Record 32 of the Set 6 | inhambane
# City not found. Skipping...
# Processing Record 33 of the Set 6 | linxia
# Processing Record 34 of the Set 6 | qianan
# Processing Record 35 of the Set 6 | shelburne
# Processing Record 36 of the Set 6 | kirakira
# Processing Record 37 of the Set 6 | ucluelet
# Processing Record 38 of the Set 6 | miles city
# Processing Record 39 of the Set 6 | ormara
# Processing Record 40 of the Set 6 | williams lake
# Processing Record 41 of the Set 6 | niquelandia
# Processing Record 42 of the Set 6 | clyde river
# Processing Record 43 of the Set 6 | puerto penasco
# Processing Record 44 of the Set 6 | yulara
# Processing Record 45 of the Set 6 | chapais
# Processing Record 46 of the Set 6 | svetlogorsk
# City not found. Skipping...
# Processing Record 47 of the Set 6 | altay
# Processing Record 48 of the Set 6 | abonnema
# Processing Record 49 of the Set 6 | barra
# Processing Record 50 of the Set 6 | grand river south east
# Processing Record 1 of the Set 7 | termoli
# Processing Record 2 of the Set 7 | puerto escondido
# Processing Record 3 of the Set 7 | morrope
# Processing Record 4 of the Set 7 | half moon bay
# Processing Record 5 of the Set 7 | turukhansk
# City not found. Skipping...
# Processing Record 6 of the Set 7 | kapit
# Processing Record 7 of the Set 7 | patiya
# City not found. Skipping...
# Processing Record 8 of the Set 7 | roswell
# Processing Record 9 of the Set 7 | xining
# Processing Record 10 of the Set 7 | nhulunbuy
# Processing Record 11 of the Set 7 | stepantsevo
# City not found. Skipping...
# Processing Record 12 of the Set 7 | faya
# Processing Record 13 of the Set 7 | asau
# Processing Record 14 of the Set 7 | abu kamal
# Processing Record 15 of the Set 7 | sorong
# Processing Record 16 of the Set 7 | zhangye
# Processing Record 17 of the Set 7 | saint-jean-de-maurienne
# Processing Record 18 of the Set 7 | mackay
# Processing Record 19 of the Set 7 | severnyy
# City not found. Skipping...
# Processing Record 20 of the Set 7 | nantucket
# Processing Record 21 of the Set 7 | xuddur
# Processing Record 22 of the Set 7 | namibe
# Processing Record 23 of the Set 7 | taywarah
# Processing Record 24 of the Set 7 | milkovo
# City not found. Skipping...
# Processing Record 25 of the Set 7 | ketchikan
# Processing Record 26 of the Set 7 | waipawa
# Processing Record 27 of the Set 7 | kavieng
# Processing Record 28 of the Set 7 | rincon
# Processing Record 29 of the Set 7 | felidhoo
# Processing Record 30 of the Set 7 | hofn
# Processing Record 31 of the Set 7 | moree
# Processing Record 32 of the Set 7 | kihei
# Processing Record 33 of the Set 7 | rungata
# City not found. Skipping...
# Processing Record 34 of the Set 7 | guder
# Processing Record 35 of the Set 7 | galich
# City not found. Skipping...
# Processing Record 36 of the Set 7 | andenes
# Processing Record 37 of the Set 7 | hasaki
# Processing Record 38 of the Set 7 | tomatlan
# Processing Record 39 of the Set 7 | juneau
# Processing Record 40 of the Set 7 | zheleznodorozhnyy
# City not found. Skipping...
# Processing Record 41 of the Set 7 | bolungarvik
# Processing Record 42 of the Set 7 | naze
# Processing Record 43 of the Set 7 | zhanaozen
# Processing Record 44 of the Set 7 | egvekinot
# City not found. Skipping...
# Processing Record 45 of the Set 7 | petropavlovsk-kamchatskiy
# City not found. Skipping...
# Processing Record 46 of the Set 7 | chagda
# City not found. Skipping...
# Processing Record 47 of the Set 7 | zwedru
# Processing Record 48 of the Set 7 | lukovetskiy
# City not found. Skipping...
# Processing Record 49 of the Set 7 | bull savanna
# Processing Record 50 of the Set 7 | hambantota
# Processing Record 1 of the Set 8 | laguna
# Processing Record 2 of the Set 8 | bathsheba
# Processing Record 3 of the Set 8 | arlit
# Processing Record 4 of the Set 8 | saint-joseph
# Processing Record 5 of the Set 8 | bunia
# Processing Record 6 of the Set 8 | baturaja
# Processing Record 7 of the Set 8 | north platte
# Processing Record 8 of the Set 8 | muros
# Processing Record 9 of the Set 8 | ust-kan
# City not found. Skipping...
# Processing Record 10 of the Set 8 | kabompo
# Processing Record 11 of the Set 8 | changli
# Processing Record 12 of the Set 8 | innisfail
# Processing Record 13 of the Set 8 | dingle
# Processing Record 14 of the Set 8 | faanui
# Processing Record 15 of the Set 8 | orthez
# Processing Record 16 of the Set 8 | norman wells
# Processing Record 17 of the Set 8 | chicama
# Processing Record 18 of the Set 8 | berlevag
# Processing Record 19 of the Set 8 | tevaitoa
# Processing Record 20 of the Set 8 | verkhnyaya maksakovka
# City not found. Skipping...
# Processing Record 21 of the Set 8 | magistralnyy
# City not found. Skipping...
# Processing Record 22 of the Set 8 | marsa matruh
# Processing Record 23 of the Set 8 | dujuma
# Processing Record 24 of the Set 8 | maarianhamina
# Processing Record 25 of the Set 8 | balikpapan
# Processing Record 26 of the Set 8 | rocha
# Processing Record 27 of the Set 8 | hamilton
# Processing Record 28 of the Set 8 | sujangarh
# Processing Record 29 of the Set 8 | kisangani
# Processing Record 30 of the Set 8 | flinders
# Processing Record 31 of the Set 8 | havelock
# Processing Record 32 of the Set 8 | kampong thum
# Processing Record 33 of the Set 8 | coihaique
# Processing Record 34 of the Set 8 | upata
# Processing Record 35 of the Set 8 | avera
# Processing Record 36 of the Set 8 | lucapa
# Processing Record 37 of the Set 8 | kaliua
# City not found. Skipping...
# Processing Record 38 of the Set 8 | hami
# Processing Record 39 of the Set 8 | filingue
# Processing Record 40 of the Set 8 | cockburn harbour
# City not found. Skipping...
# Processing Record 41 of the Set 8 | luangwa
# Processing Record 42 of the Set 8 | ambodifototra
# City not found. Skipping...
# Processing Record 43 of the Set 8 | jalu
# Processing Record 44 of the Set 8 | poronaysk
# City not found. Skipping...
# Processing Record 45 of the Set 8 | tucurui
# Processing Record 46 of the Set 8 | portland
# Processing Record 47 of the Set 8 | vila velha
# Processing Record 48 of the Set 8 | nanortalik
# Processing Record 49 of the Set 8 | grand-santi
# Processing Record 50 of the Set 8 | coquimbo
# Processing Record 1 of the Set 9 | gubkinskiy
# City not found. Skipping...
# Processing Record 2 of the Set 9 | north port
# Processing Record 3 of the Set 9 | espanola
# Processing Record 4 of the Set 9 | porto velho
# Processing Record 5 of the Set 9 | cairns
# Processing Record 6 of the Set 9 | nuuk
# Processing Record 7 of the Set 9 | saint-louis
# Processing Record 8 of the Set 9 | itajuipe
# Processing Record 9 of the Set 9 | along
# Processing Record 10 of the Set 9 | anloga
# Processing Record 11 of the Set 9 | beira
# City not found. Skipping...
# Processing Record 12 of the Set 9 | adrar
# City not found. Skipping...
# Processing Record 13 of the Set 9 | san luis
# Processing Record 14 of the Set 9 | helong
# Processing Record 15 of the Set 9 | vanimo
# Processing Record 16 of the Set 9 | maniitsoq
# Processing Record 17 of the Set 9 | jahrom
# Processing Record 18 of the Set 9 | teguldet
# City not found. Skipping...
# Processing Record 19 of the Set 9 | floro
# Processing Record 20 of the Set 9 | kavaratti
# Processing Record 21 of the Set 9 | revuca
# Processing Record 22 of the Set 9 | lorengau
# Processing Record 23 of the Set 9 | coahuayana
# Processing Record 24 of the Set 9 | dubbo
# Processing Record 25 of the Set 9 | buraydah
# Processing Record 26 of the Set 9 | immokalee
# Processing Record 27 of the Set 9 | esso
# City not found. Skipping...
# Processing Record 28 of the Set 9 | yugo-kamskiy
# City not found. Skipping...
# Processing Record 29 of the Set 9 | nouadhibou
# Processing Record 30 of the Set 9 | baruun-urt
# Processing Record 31 of the Set 9 | baracoa
# Processing Record 32 of the Set 9 | smirnykh
# City not found. Skipping...
# Processing Record 33 of the Set 9 | puerto suarez
# Processing Record 34 of the Set 9 | sharjah
# Processing Record 35 of the Set 9 | tuscaloosa
# Processing Record 36 of the Set 9 | attawapiskat
# Processing Record 37 of the Set 9 | karaul
# City not found. Skipping...
# Processing Record 38 of the Set 9 | labuhan
# Processing Record 39 of the Set 9 | sorvag
# Processing Record 40 of the Set 9 | magdagachi
# City not found. Skipping...
# Processing Record 41 of the Set 9 | palana
# City not found. Skipping...
# Processing Record 42 of the Set 9 | catamarca
# Processing Record 43 of the Set 9 | latung
# City not found. Skipping...
# Processing Record 44 of the Set 9 | andijon
# City not found. Skipping...
# Processing Record 45 of the Set 9 | luanda
# Processing Record 46 of the Set 9 | amboasary
# Processing Record 47 of the Set 9 | haines junction
# Processing Record 48 of the Set 9 | lac du bonnet
# Processing Record 49 of the Set 9 | broken hill
# Processing Record 50 of the Set 9 | uk
# City not found. Skipping...
# Processing Record 1 of the Set 10 | huarmey
# Processing Record 2 of the Set 10 | yarim
# Processing Record 3 of the Set 10 | pandan
# City not found. Skipping...
# Processing Record 4 of the Set 10 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 5 of the Set 10 | swan hill
# Processing Record 6 of the Set 10 | bireun
# Processing Record 7 of the Set 10 | bur gabo
# Processing Record 8 of the Set 10 | cubuk
# Processing Record 9 of the Set 10 | edmundston
# Processing Record 10 of the Set 10 | ostrovskoye
# City not found. Skipping...
# Processing Record 11 of the Set 10 | boca do acre
# Processing Record 12 of the Set 10 | kalmunai
# Processing Record 13 of the Set 10 | kristiansund
# Processing Record 14 of the Set 10 | biak
# Processing Record 15 of the Set 10 | samarai
# Processing Record 16 of the Set 10 | kaeo
# Processing Record 17 of the Set 10 | kuche
# Processing Record 18 of the Set 10 | pendleton
# Processing Record 19 of the Set 10 | polunochnoye
# Processing Record 20 of the Set 10 | asyut
# Processing Record 21 of the Set 10 | polyarnyy
# Processing Record 22 of the Set 10 | meulaboh
# Processing Record 23 of the Set 10 | palabuhanratu
# Processing Record 24 of the Set 10 | goderich
# Processing Record 25 of the Set 10 | vardo
# Processing Record 26 of the Set 10 | maloy
# Processing Record 27 of the Set 10 | kant
# Processing Record 28 of the Set 10 | dyersburg
# Processing Record 29 of the Set 10 | lata
# Processing Record 30 of the Set 10 | friesach
# Processing Record 31 of the Set 10 | itupeva
# Processing Record 32 of the Set 10 | plouzane
# Processing Record 33 of the Set 10 | ixtapa
# Processing Record 34 of the Set 10 | daru
# Processing Record 35 of the Set 10 | maromitsa
# Processing Record 36 of the Set 10 | carnot
# Processing Record 37 of the Set 10 | san-pedro
# Processing Record 38 of the Set 10 | trairi
# Processing Record 39 of the Set 10 | humaita
# Processing Record 40 of the Set 10 | dunedin
# Processing Record 41 of the Set 10 | cap estate
# Processing Record 42 of the Set 10 | sawtell
# Processing Record 43 of the Set 10 | ahuimanu
# Processing Record 44 of the Set 10 | imbituba
# Processing Record 45 of the Set 10 | sabang
# Processing Record 46 of the Set 10 | chillicothe
# Processing Record 47 of the Set 10 | ariquemes
# Processing Record 48 of the Set 10 | linhares
# Processing Record 49 of the Set 10 | kholtoson
# Processing Record 50 of the Set 10 | murray
# Processing Record 1 of the Set 11 | nome
# Processing Record 2 of the Set 11 | marathon
# Processing Record 3 of the Set 11 | baghdad
# Processing Record 4 of the Set 11 | neiafu
# Processing Record 5 of the Set 11 | deputatskiy
# Processing Record 6 of the Set 11 | macusani
# Processing Record 7 of the Set 11 | sambava
# Processing Record 8 of the Set 11 | bikin
# Processing Record 9 of the Set 11 | yarada
# Processing Record 10 of the Set 11 | mecca
# Processing Record 11 of the Set 11 | kourou
# Processing Record 12 of the Set 11 | constitucion
# Processing Record 13 of the Set 11 | mandera
# Processing Record 14 of the Set 11 | atikokan
# Processing Record 15 of the Set 11 | port hardy
# Processing Record 16 of the Set 11 | quixada
# Processing Record 17 of the Set 11 | bama
# Processing Record 18 of the Set 11 | raudeberg
# Processing Record 19 of the Set 11 | flin flon
# Processing Record 20 of the Set 11 | devonport
# Processing Record 21 of the Set 11 | opuwo
# Processing Record 22 of the Set 11 | ouesso
# Processing Record 23 of the Set 11 | narsaq
# Processing Record 24 of the Set 11 | tuatapere
# Processing Record 25 of the Set 11 | graham
# Processing Record 26 of the Set 11 | baeza
# Processing Record 27 of the Set 11 | shush
# Processing Record 28 of the Set 11 | sao felix do xingu
# Processing Record 29 of the Set 11 | camaqua
# Processing Record 30 of the Set 11 | ginda
# Processing Record 31 of the Set 11 | banda aceh
# Processing Record 32 of the Set 11 | nouakchott
# Processing Record 33 of the Set 11 | nemuro
# Processing Record 34 of the Set 11 | cidreira
# Processing Record 35 of the Set 11 | panguna
# Processing Record 36 of the Set 11 | salmas
# Processing Record 37 of the Set 11 | lujiang
# Processing Record 38 of the Set 11 | tynda
# Processing Record 39 of the Set 11 | saryozek
# Processing Record 40 of the Set 11 | yerbogachen
# Processing Record 41 of the Set 11 | gazojak
# Processing Record 42 of the Set 11 | tangshan
# Processing Record 43 of the Set 11 | porto novo
# Processing Record 44 of the Set 11 | acari
# Processing Record 45 of the Set 11 | sao joao da barra
# Processing Record 46 of the Set 11 | the valley
# Processing Record 47 of the Set 11 | mbandaka
# Processing Record 48 of the Set 11 | kokstad
# Processing Record 49 of the Set 11 | paralimni
# Processing Record 50 of the Set 11 | touros
# Processing Record 1 of the Set 12 | constitucion
# Processing Record 2 of the Set 12 | jingdezhen
# Processing Record 3 of the Set 12 | bazarnyy karabulak
# Processing Record 4 of the Set 12 | bartica
# Processing Record 5 of the Set 12 | santa maria
# Processing Record 6 of the Set 12 | mutum
# Processing Record 7 of the Set 12 | jashpurnagar
# Processing Record 8 of the Set 12 | sangar
# Processing Record 9 of the Set 12 | griffith
# Processing Record 10 of the Set 12 | puteyets
# Processing Record 11 of the Set 12 | makat
# Processing Record 12 of the Set 12 | qaqortoq
# Processing Record 13 of the Set 12 | mizdah
# Processing Record 14 of the Set 12 | macalva
# City not found. Skipping...
# Processing Record 15 of the Set 12 | kudahuvadhoo
# Processing Record 16 of the Set 12 | sofiysk
# Processing Record 17 of the Set 12 | lompoc
# Processing Record 18 of the Set 12 | surt
# Processing Record 19 of the Set 12 | kupang
# Processing Record 20 of the Set 12 | port hedland
# Processing Record 21 of the Set 12 | morondava
# Processing Record 22 of the Set 12 | talas
# Processing Record 23 of the Set 12 | contepec
# Processing Record 24 of the Set 12 | mahibadhoo
# Processing Record 25 of the Set 12 | waling
# Processing Record 26 of the Set 12 | nguiu
# Processing Record 27 of the Set 12 | urusha
# Processing Record 28 of the Set 12 | ilulissat
# Processing Record 29 of the Set 12 | wattegama
# Processing Record 30 of the Set 12 | bilibino
# Processing Record 31 of the Set 12 | calvinia
# Processing Record 32 of the Set 12 | boguchany
# Processing Record 33 of the Set 12 | opunake
# Processing Record 34 of the Set 12 | tautira
# Processing Record 35 of the Set 12 | termiz
# Processing Record 36 of the Set 12 | cockburn town
# Processing Record 37 of the Set 12 | sataua
# City not found. Skipping...
# Processing Record 38 of the Set 12 | muli
# Processing Record 39 of the Set 12 | wulanhaote
# Processing Record 40 of the Set 12 | mufumbwe
# Processing Record 41 of the Set 12 | avallon
# Processing Record 42 of the Set 12 | benguela
# Processing Record 43 of the Set 12 | brae
# Processing Record 44 of the Set 12 | revelstoke
# Processing Record 45 of the Set 12 | kerteh
# Processing Record 46 of the Set 12 | vestmanna
# Processing Record 47 of the Set 12 | muscat
# Processing Record 48 of the Set 12 | ostersund
# Processing Record 49 of the Set 12 | stromness
# Processing Record 50 of the Set 12 | dali
# Processing Record 1 of the Set 13 | quatre cocos
# Processing Record 2 of the Set 13 | nagato
# Processing Record 3 of the Set 13 | medvezhyegorsk
# Processing Record 4 of the Set 13 | saint-pierre
# Processing Record 5 of the Set 13 | shingu
# Processing Record 6 of the Set 13 | valdez
# Processing Record 7 of the Set 13 | kerchevskiy
# Processing Record 8 of the Set 13 | saleilua
# City not found. Skipping...
# Processing Record 9 of the Set 13 | major isidoro
# Processing Record 10 of the Set 13 | dakar
# Processing Record 11 of the Set 13 | marsh harbour
# Processing Record 12 of the Set 13 | yumen
# Processing Record 13 of the Set 13 | yenagoa
# Processing Record 14 of the Set 13 | artesia
# Processing Record 15 of the Set 13 | ailigandi
# Processing Record 16 of the Set 13 | kaspiyskiy
# Processing Record 17 of the Set 13 | dandong
# Processing Record 18 of the Set 13 | whitehorse
# Processing Record 19 of the Set 13 | vestmannaeyjar
# Processing Record 20 of the Set 13 | atambua
# Processing Record 21 of the Set 13 | brasilia de minas
# Processing Record 22 of the Set 13 | nishihara
# Processing Record 23 of the Set 13 | chiredzi
# Processing Record 24 of the Set 13 | netanya
# Processing Record 25 of the Set 13 | rundu
# Processing Record 26 of the Set 13 | maldonado
# Processing Record 27 of the Set 13 | tasbuget
# Processing Record 28 of the Set 13 | kesova gora
# Processing Record 29 of the Set 13 | roebourne
# Processing Record 30 of the Set 13 | paamiut
# Processing Record 31 of the Set 13 | endicott
# Processing Record 32 of the Set 13 | sicuani
# Processing Record 33 of the Set 13 | ayan
# Processing Record 34 of the Set 13 | juifang
# City not found. Skipping...
# Processing Record 35 of the Set 13 | acapulco
# Processing Record 36 of the Set 13 | cayenne
# Processing Record 37 of the Set 13 | lahaina
# Processing Record 38 of the Set 13 | axim
# Processing Record 39 of the Set 13 | tabiauea
# City not found. Skipping...
# Processing Record 40 of the Set 13 | westport
# Processing Record 41 of the Set 13 | rock sound
# Processing Record 42 of the Set 13 | benjamin constant
# Processing Record 43 of the Set 13 | shimoda
# Processing Record 44 of the Set 13 | manado
# Processing Record 45 of the Set 13 | aracati
# Processing Record 46 of the Set 13 | aksarka
# Processing Record 47 of the Set 13 | elko
# Processing Record 48 of the Set 13 | conde
# Processing Record 49 of the Set 13 | nha trang
# Processing Record 50 of the Set 13 | el alto
# Processing Record 1 of the Set 14 | hunza
# Processing Record 2 of the Set 14 | boden
# Processing Record 3 of the Set 14 | apex
# Processing Record 4 of the Set 14 | limbach-oberfrohna
# Processing Record 5 of the Set 14 | kangaatsiaq
# Processing Record 6 of the Set 14 | burkhala
# Processing Record 7 of the Set 14 | moranbah
# Processing Record 8 of the Set 14 | conakry
# Processing Record 9 of the Set 14 | matay
# Processing Record 10 of the Set 14 | karasuk
# Processing Record 11 of the Set 14 | basavana bagevadi
# Processing Record 12 of the Set 14 | tapaua
# Processing Record 13 of the Set 14 | sassandra
# Processing Record 14 of the Set 14 | sao joao da boa vista
# Processing Record 15 of the Set 14 | slave lake
# Processing Record 16 of the Set 14 | shaowu
# Processing Record 17 of the Set 14 | acarau
# Processing Record 18 of the Set 14 | maceio
# Processing Record 19 of the Set 14 | negombo
# Processing Record 20 of the Set 14 | jabiru
# Processing Record 21 of the Set 14 | namie
# Processing Record 22 of the Set 14 | neijiang
# Processing Record 23 of the Set 14 | nanakuli
# Processing Record 24 of the Set 14 | sinegorye
# Processing Record 25 of the Set 14 | maghama
# Processing Record 26 of the Set 14 | broome
# Processing Record 27 of the Set 14 | acajutla
# Processing Record 28 of the Set 14 | phultala
# Processing Record 29 of the Set 14 | ilo
# Processing Record 30 of the Set 14 | kachikau
# Processing Record 31 of the Set 14 | isoka
# Processing Record 32 of the Set 14 | stephenville
# Processing Record 33 of the Set 14 | ivanivka
# Processing Record 34 of the Set 14 | conceicao da barra
# Processing Record 35 of the Set 14 | havoysund
# Processing Record 36 of the Set 14 | kamenka
# Processing Record 37 of the Set 14 | gay
# Processing Record 38 of the Set 14 | port augusta
# Processing Record 39 of the Set 14 | benemerito de las americas
# Processing Record 40 of the Set 14 | puerto lopez
# Processing Record 41 of the Set 14 | ust-omchug
# Processing Record 42 of the Set 14 | santa rosa
# Processing Record 43 of the Set 14 | bairiki
# City not found. Skipping...
# Processing Record 44 of the Set 14 | dhupgari
# Processing Record 45 of the Set 14 | carutapera
# Processing Record 46 of the Set 14 | alofi
# Processing Record 47 of the Set 14 | jiangkou
# Processing Record 48 of the Set 14 | tiarei
# Processing Record 49 of the Set 14 | paradwip
# Processing Record 50 of the Set 14 | samusu
# City not found. Skipping...
# Processing Record 1 of the Set 15 | mulege
# Processing Record 2 of the Set 15 | batemans bay
# Processing Record 3 of the Set 15 | bubaque
# Processing Record 4 of the Set 15 | scarborough
# Processing Record 5 of the Set 15 | baker city
# Processing Record 6 of the Set 15 | umm lajj
# Processing Record 7 of the Set 15 | haibowan
# Processing Record 8 of the Set 15 | superior
# Processing Record 9 of the Set 15 | westport
# Processing Record 10 of the Set 15 | abu samrah
# Processing Record 11 of the Set 15 | bibiani
# Processing Record 12 of the Set 15 | hay river
# Processing Record 13 of the Set 15 | xiongshi
# Processing Record 14 of the Set 15 | nemea
# Processing Record 15 of the Set 15 | korem
# Processing Record 16 of the Set 15 | langsa
# Processing Record 17 of the Set 15 | meadow lake
# Processing Record 18 of the Set 15 | bereda
# Processing Record 19 of the Set 15 | abay
# Processing Record 20 of the Set 15 | guimar
# Processing Record 21 of the Set 15 | geraldton
# Processing Record 22 of the Set 15 | serebryansk
# Processing Record 23 of the Set 15 | yar-sale
# Processing Record 24 of the Set 15 | keetmanshoop
# Processing Record 25 of the Set 15 | aksu
# Processing Record 26 of the Set 15 | vilcun
# Processing Record 27 of the Set 15 | kuvshinovo
# Processing Record 28 of the Set 15 | ler
# Processing Record 29 of the Set 15 | san cristobal
# Processing Record 30 of the Set 15 | wanxian
# Processing Record 31 of the Set 15 | mitsamiouli
# Processing Record 32 of the Set 15 | qala
# Processing Record 33 of the Set 15 | ilula
# Processing Record 34 of the Set 15 | qinhuangdao
# Processing Record 35 of the Set 15 | pafos
# Processing Record 36 of the Set 15 | mayna
# Processing Record 37 of the Set 15 | puerto del rosario
# Processing Record 38 of the Set 15 | gboko
# Processing Record 39 of the Set 15 | raga
# Processing Record 40 of the Set 15 | xuanhua
# Processing Record 41 of the Set 15 | hudson bay
# Processing Record 42 of the Set 15 | lloydminster
# Processing Record 43 of the Set 15 | mount isa
# Processing Record 44 of the Set 15 | oranjemund
# Processing Record 45 of the Set 15 | port antonio
# Processing Record 46 of the Set 15 | vandra
# Processing Record 47 of the Set 15 | port ellen
# Processing Record 48 of the Set 15 | tilichiki
# Processing Record 49 of the Set 15 | santa cruz
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Check numer of cities
len(city_data)
# Out:
# 637

# %%
# Add data to a new DataFrame
cities_weather_df = pd.DataFrame(city_data)
# Reorder the columns
cities_weather_df=cities_weather_df[["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]]
cities_weather_df.head()
# Out:
#         City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Itaituba      BR  -4.2761  -55.9836     82.92        45          99
# 1      Bluff      NZ -46.6000  168.3333     59.81        70         100
# 2     Rawson      AR -43.3002  -65.1023     46.83        48           0
# 3  Geraldton      AU -28.7667  114.6000     63.01        59           0
# 4    Aklavik      CA  68.2191 -135.0107     65.12        57          90
#
#    Wind Speed Current Description
# 0        1.79     overcast clouds
# 1       17.40     overcast clouds
# 2       10.87           clear sky
# 3       16.11           clear sky
# 4        1.79     overcast clouds

# %%
output_data_file = "data/WeatherPy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
