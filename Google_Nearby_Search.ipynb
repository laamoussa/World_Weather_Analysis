# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps
from config import g_key

# %%
# Set the parameters to search for a hotel in Paris.
params =  {
    "type": "lodging",
    "radius": 5000,
    "key": g_key,
    #"location": "48.864716,2.349014"
    "location": "-16.48,-151.75"
}
# Use base URL to search for hotels in Paris.
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
# Make request and get the JSON data from the search.
hotels = requests.get(base_url, params=params).json()
hotels
# Out:
# {'html_attributions': [],
#  'next_page_token': 'Aap_uEA9zUhkohPGMkx3_m0KvXsBbyBTamw-ugaISCzoTuewfmHwYkDhkUC75uQpB0jQyjk4NFIN0tNueQ13r41hIXbDD-S5xjNySqGJ2Oeffvgf1fhWRQ9nxnMwkr-4K6tURtoo6NCQaGJPbKLydJx0BCLtcGLOR4btvHq4QKckbfK9YtNjuuLDLepqdtwMvQgTdRq9bBHwXFIp4J5ns_EGXTvWb4gZpbgz46msmawKysV4Lm6-nNirhYxEN9tg7yfq9EdTkUDCNR8n7Fm7nl2mJP7EKvvqYPfoKBXwv1M2q8kR7ZoL9aPAdVotRuw-tu38f_EDlikyjnUhJLp6YKvtcuTVXj00rqEhcjGmgrm9Rg4qC6_Q8geVe21snhIQsCAlMqvA23CkKD4BHFrd8oc5uyb8lt_5ORqEa5rFyTxZqBYHDBjEEljwJECe',
#  'results': [{'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -16.4759407, 'lng': -151.7724793},
#     'viewport': {'northeast': {'lat': -16.47405801970849,
#       'lng': -151.7710643197085},
#      'southwest': {'lat': -16.4767559802915, 'lng': -151.7737622802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Bora-Bora Pearl Beach Resort & Spa',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 999,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/104246194359653987357">Le Bora Bora by Pearl Resorts</a>'],
#      'photo_reference': 'Aap_uEBqAYSSJIWblY-WbamOtS1i9zRHp5jIUJZjU8RUTOIzKViZSvVGFA7PPK1Cy4lOdzD2CJuRDLW36jt5lWJ-Ya7JMzJ2hQSHrQmYYGEyq9MWcbIpeXXPZDFiXc0xb5XuqL4RybGd9VAzSJHa8gmqpeOuG7Ro955JIcNBHniII-XX_2BU',
#      'width': 1500}],
#    'place_id': 'ChIJH4mb5268vXYRv4OyGEc8kr0',
#    'plus_code': {'compound_code': 'G6FH+J2 Bora-Bora, French Polynesia',
#     'global_code': '53MCG6FH+J2'},
#    'rating': 4.7,
#    'reference': 'ChIJH4mb5268vXYRv4OyGEc8kr0',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 612,
#    'vicinity': 'Vaitape'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -16.4501748, 'lng': -151.736834},
#     'viewport': {'northeast': {'lat': -16.4488258197085,
#       'lng': -151.7354850197085},
#      'southwest': {'lat': -16.4515237802915, 'lng': -151.7381829802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Pension Alice et Raphael Bora-Bora',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2736,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108883341364757871748">Emilie Marçais</a>'],
#      'photo_reference': 'Aap_uECe9k6TVtMqoRCeNajJ4l5n22o49ymd4LZV_jLjy8ccWMIaM5bHqKxHHZzf_EIkvdCb1bsB38CKN-NMNjPtEHSY5jq5SzJoSyP-scaGk-BT2_MpSXrTr6r8yQQbZuXoXuKqUhvM72Y_wa0axNS8q_orV6IlxH-RDo3M4ZO2A5A4EUWC',
#      'width': 3648}],
#    'place_id': 'ChIJZU0_a9C9vXYR5iX0lQQGXkE',
#    'plus_code': {'compound_code': 'G7X7+W7 Bora-Bora, French Polynesia',
#     'global_code': '53MCG7X7+W7'},
#    'rating': 4.8,
#    'reference': 'ChIJZU0_a9C9vXYR5iX0lQQGXkE',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 26,
#    'vicinity': 'Motu Ome'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -16.449585, 'lng': -151.766166},
#     'viewport': {'northeast': {'lat': -16.4482360197085,
#       'lng': -151.7648170197085},
#      'southwest': {'lat': -16.4509339802915, 'lng': -151.7675149802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Blue Heaven Island',
#    'photos': [{'height': 768,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/116013504863822137968">AHMET ENES YAPRAK</a>'],
#      'photo_reference': 'Aap_uEBFDFSwHB7xqL23iKdUf6sNStkDXYYr6mcbcUHRHGrMgOCsST1Biv0tdFjzi4LNMaVic0kPWBDsTcUyH9sLegLEQR59R6I5L3Xg33wJWxygCpmB0WMBFv0SO9OITfQ313n5ANaC7nfxzFUskSwegb7Qd5CfQSV81MPVNs58pG1uBY88',
#      'width': 1024}],
#    'place_id': 'ChIJi2A1QiG8vXYR2k315sjeyqg',
#    'rating': 4.8,
#    'reference': 'ChIJi2A1QiG8vXYR2k315sjeyqg',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 21,
#    'vicinity': 'H62M+5G8, Bora-Bora'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -16.4729859, 'lng': -151.7058542},
#     'viewport': {'northeast': {'lat': -16.4716369197085,
#       'lng': -151.7045052197085},
#      'southwest': {'lat': -16.4743348802915, 'lng': -151.7072031802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Four Seasons Resort Bora Bora',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1050,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111626393195503955828">Four Seasons Resort Bora Bora</a>'],
#      'photo_reference': 'Aap_uEBAdjtXr2Ut4iTpapxduerRm2LVyQe7HPp8DCPOZEDzOa25Rh5JVd-9-y1tgqK3DkvplfOJE3am4yHABj7Rp8WLE95riYM9lNki8ZvW4_ZgmkJp6WzrNH__ClXh-OpMfwmyOInwBsURfNe9Uon1cxP3mO6yXKZH23EKk-7LfF82Zy1i',
#      'width': 1313}],
#    'place_id': 'ChIJB_VVzoa9vXYRguWsYU0H8eU',
#    'plus_code': {'compound_code': 'G7GV+RM Bora-Bora, French Polynesia',
#     'global_code': '53MCG7GV+RM'},
#    'rating': 4.7,
#    'reference': 'ChIJB_VVzoa9vXYRguWsYU0H8eU',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 583,
#    'vicinity': 'French Polynesia'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -16.46620799999999, 'lng': -151.7509854},
#     'viewport': {'northeast': {'lat': -16.46474586970849,
#       'lng': -151.7496928697085},
#      'southwest': {'lat': -16.4674438302915, 'lng': -151.7523908302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Bora Bora Bungalow - Here Moana',
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106588576173071631542">Denis Renko</a>'],
#      'photo_reference': 'Aap_uEBB81SPnolsQn1fJ6HYV_xFA3bT7FzRsdaR9soCEtLir3hcIk6-JAjhdh3-nk2P6Qt1yLo_eU0gCN0AhRX18jK0X1oZgXWR2C9v7rlPsFJr-pWmUeJU86iIQHSwEa06tSX21m2y7wNO3xftMWsXTSL-mKgSyXuVxxqXhwdj7AHflEQz',
#      'width': 4032}],
#    'place_id': 'ChIJTWvTWkq8vXYR4xg4AfGM7BU',
#    'plus_code': {'compound_code': 'G6MX+GJ Bora-Bora, French Polynesia',
#     'global_code': '53MCG6MX+GJ'},
#    'rating': 5,
#    'reference': 'ChIJTWvTWkq8vXYR4xg4AfGM7BU',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 25,
#    'vicinity': 'Bungalow 12, BP 818 Bora Bora Main Road'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -16.4976468, 'lng': -151.7545068},
#     'viewport': {'northeast': {'lat': -16.4963299197085,
#       'lng': -151.7530945197085},
#      'southwest': {'lat': -16.4990278802915, 'lng': -151.7557924802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Sunset Hill Lodge',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 720,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111161129596882168438">SUNSET HILL LODGE</a>'],
#      'photo_reference': 'Aap_uEDHePlLf34ULQsQWscRQS6l_WT9rjwgFsocbadUwp2_DsCpQosheVhNKROzBHfltMt08B_86i9cGSvMSkd2AdNP_I_lVRjvtNwUVGXtnq2N_QX6mEQ_uWvSZaIA0_c8Jlvy7ZTjiJfPbCwpCV0fiDBjyax7xfTgb781QnXw1ClfRGBH',
#      'width': 960}],
#    'place_id': 'ChIJVy2zueS8vXYRf18-bl1BwGQ',
#    'plus_code': {'compound_code': 'G62W+W5 Bora-Bora, French Polynesia',
#     'global_code': '53MCG62W+W5'},
#    'rating': 4.4,
#    'reference': 'ChIJVy2zueS8vXYRf18-bl1BwGQ',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 49,
#    'vicinity': 'Vaitape'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -16.49885039999999, 'lng': -151.7570304},
#     'viewport': {'northeast': {'lat': -16.4974196697085,
#       'lng': -151.7556685197085},
#      'southwest': {'lat': -16.5001176302915, 'lng': -151.7583664802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'オア オア ロッジ',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 1367,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100645999583288005221">Oa Oa Lodge</a>'],
#      'photo_reference': 'Aap_uEDULwPKiXlmknRsB3GOvf9HlYuHNqHUT9nPnFNKbtW66vU1J_I3489gPgkN40ug546XgngUfKNxU0X9y99qqthd2thdl2awz9GPGvm4saDARiVOOAzYQ3KUH7Z8LeAtWLn0MmeFHN8WwuNRSJ80CHzOkx00dUNzFMWkKjozl-Fs8r-3',
#      'width': 2048}],
#    'place_id': 'ChIJ00z-FuW8vXYRGhHqMHIHi08',
#    'plus_code': {'compound_code': 'G62V+F5 Bora-Bora, French Polynesia',
#     'global_code': '53MCG62V+F5'},
#    'rating': 4.1,
#    'reference': 'ChIJ00z-FuW8vXYRGhHqMHIHi08',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 76,
#    'vicinity': 'Vaitape'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -16.4569942, 'lng': -151.7706299},
#     'viewport': {'northeast': {'lat': -16.4556452197085,
#       'lng': -151.7692809197085},
#      'southwest': {'lat': -16.4583431802915, 'lng': -151.7719788802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Bora Bora Ecolodge - Pension du Motu',
#    'photos': [{'height': 2825,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109274380857936682297">bernardo tejada</a>'],
#      'photo_reference': 'Aap_uECUR92lOhlYsAkp5yEFpVsx7tIpdn5sggEFHNRrXD4ICuDwontN4i2a7Ekpn6Kiwo7_ynpCO3LPA5Vfq8P2cGjYXAGko0PjaZEtRl1DPBKIsp9n1r3XLhKyy6QCWfg2YFrw2hMzIt6oKrvwawL0GAE_XSI9HnQDle2OMNMw4LzmYTo',
#      'width': 4122}],
#    'place_id': 'ChIJ4UZKVj28vXYRmYKv7u_E5R4',
#    'rating': 5,
#    'reference': 'ChIJ4UZKVj28vXYRmYKv7u_E5R4',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 6,
#    'vicinity': 'G6VH+6P5, Bora-Bora'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -16.5062723, 'lng': -151.7495305},
#     'viewport': {'northeast': {'lat': -16.50502446970849,
#       'lng': -151.7481562697085},
#      'southwest': {'lat': -16.5077224302915, 'lng': -151.7508542302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Pension Robert et Tina',
#    'place_id': 'ChIJVVVVZeC8vXYRrPjhjYGwzf8',
#    'rating': 3.5,
#    'reference': 'ChIJVVVVZeC8vXYRrPjhjYGwzf8',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 2,
#    'vicinity': 'Vaitape'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -16.5216154, 'lng': -151.7323933},
#     'viewport': {'northeast': {'lat': -16.5202185697085,
#       'lng': -151.7310152197085},
#      'southwest': {'lat': -16.5229165302915, 'lng': -151.7337131802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Bora Faretai Love',
#    'photos': [{'height': 1536,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109330373654559131709">Milona Vane</a>'],
#      'photo_reference': 'Aap_uEDFpEO6iGbOuOorO9ci8DeVvpVNl2ZLF4WaQLXZBIIb3LrxwyS7CyJTHr1HnLeSMFR17b90I7sxquJPWJuEBNXvii5EpdWkmL-LTYiAbLve4HeWN_yWYqYnP3K6ywvgeHa_slJlOlofcom8JLBYjbUzxUD2PyNMRt9CSO5dpftsVvH6',
#      'width': 2048}],
#    'place_id': 'ChIJQ57ayzO9vXYRV1xXQbigJqE',
#    'plus_code': {'compound_code': 'F7H9+92 Bora-Bora, French Polynesia',
#     'global_code': '53MCF7H9+92'},
#    'rating': 4.2,
#    'reference': 'ChIJQ57ayzO9vXYRV1xXQbigJqE',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 12,
#    'vicinity': 'Bora-Bora'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -16.4789605, 'lng': -151.7525535},
#     'viewport': {'northeast': {'lat': -16.4777446197085,
#       'lng': -151.7512771697085},
#      'southwest': {'lat': -16.48044258029151, 'lng': -151.7539751302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Teina Pascale',
#    'place_id': 'ChIJk7-1sf29vXYR9VYHPUQtVJc',
#    'reference': 'ChIJk7-1sf29vXYR9VYHPUQtVJc',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': 'G6CW+CX8, Bora-Bora'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -16.48467, 'lng': -151.74431},
#     'viewport': {'northeast': {'lat': -16.4833069197085,
#       'lng': -151.7429487197085},
#      'southwest': {'lat': -16.4860048802915, 'lng': -151.7456466802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Bora Bora Bungalove',
#    'photos': [{'height': 2800,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113891135027852008740">nathalie Coho</a>'],
#      'photo_reference': 'Aap_uECdd8dO8cmOIP7gai5u7R-4L5udwM8US0Qa5AnuIpitn2jGLV5nTu1RyD6Lxb28TSdz9hnfQ7IVif97NrhMAHIaH4WF-J5506bFVD0Se7M-8rtaD1ts0f2yhfiXn82qp_LWKXsaCS_saXlCiAKS1Ecys3ViWoTsTV77oFx4_WniP7Ht',
#      'width': 4976}],
#    'place_id': 'ChIJb8G-f6q9vXYRvu9jLyhWx28',
#    'rating': 4.8,
#    'reference': 'ChIJb8G-f6q9vXYRvu9jLyhWx28',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 29,
#    'vicinity': 'G784+47P, Bora-Bora'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -16.4901518, 'lng': -151.7542594},
#     'viewport': {'northeast': {'lat': -16.48873691970849,
#       'lng': -151.7528237197085},
#      'southwest': {'lat': -16.4914348802915, 'lng': -151.7555216802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Chez Michel',
#    'photos': [{'height': 2268,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115809035518279877325">Sébatien Jean</a>'],
#      'photo_reference': 'Aap_uEAPTHF8hLmZaiPu5tZfU8sQemyzxwltEDywAiA5tHftxR6nEGYS6fbca1B1eIiYM5fkTJIroVvpXG4kmVJ5UojVIK1RKgZCvB7MGjdLQuxp4Tybp3oS54S0CWT5i9Vo8UUqel92CDp1TiqUKfLapKHyBzJdC97d-zvNV8aOepfenhTi',
#      'width': 4032}],
#    'place_id': 'ChIJex7KOPm8vXYRSri1C29nic4',
#    'plus_code': {'compound_code': 'G65W+W7 Bora-Bora, French Polynesia',
#     'global_code': '53MCG65W+W7'},
#    'rating': 4.3,
#    'reference': 'ChIJex7KOPm8vXYRSri1C29nic4',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 4,
#    'vicinity': 'Bora-Bora, Polynésie française'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -16.4737653, 'lng': -151.7404551},
#     'viewport': {'northeast': {'lat': -16.4724032197085,
#       'lng': -151.7390601197085},
#      'southwest': {'lat': -16.4751011802915, 'lng': -151.7417580802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Bora Vaite Lodge',
#    'photos': [{'height': 692,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103956249885868522751">Vaite Wernert</a>'],
#      'photo_reference': 'Aap_uECFGqya1qIxzKeilId80Bbk9sWkWSOMsHXPI9TwlFWQ2xzqDkd9KFaKgo861rIHl2ipxgVbIWHMZEcp692kuyQIUL73QUx28uzcbbWaouyr7-l8WotZUpIHcBT4YWRWN3h1w0PmFtXB8OBaMznVIqukuO_RYE3s5ryAHmIjfZtj5yV1',
#      'width': 1200}],
#    'place_id': 'ChIJg9sGdxG9vXYRV4gT69Uuofo',
#    'rating': 5,
#    'reference': 'ChIJg9sGdxG9vXYRV4gT69Uuofo',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1,
#    'vicinity': 'G7G5+FRV, Bora-Bora'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -16.4690807, 'lng': -151.7541687},
#     'viewport': {'northeast': {'lat': -16.4677112697085,
#       'lng': -151.7528916197085},
#      'southwest': {'lat': -16.47040923029151, 'lng': -151.7555895802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Orama Lodge Bora Bora',
#    'place_id': 'ChIJt8vFkfq9vXYR1g_aLikWuY8',
#    'plus_code': {'compound_code': 'G6JW+98 Bora-Bora, French Polynesia',
#     'global_code': '53MCG6JW+98'},
#    'reference': 'ChIJt8vFkfq9vXYR1g_aLikWuY8',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': 'Bora-Bora'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -16.4875962, 'lng': -151.7407595},
#     'viewport': {'northeast': {'lat': -16.4860598697085,
#       'lng': -151.7393355697085},
#      'southwest': {'lat': -16.4887578302915, 'lng': -151.7420335302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Tefaremaolodge',
#    'place_id': 'ChIJETj5qh29vXYRycfRsgFIl5k',
#    'plus_code': {'compound_code': 'G765+XM Bora-Bora, French Polynesia',
#     'global_code': '53MCG765+XM'},
#    'reference': 'ChIJETj5qh29vXYRycfRsgFIl5k',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': ''},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -16.4875962, 'lng': -151.7407595},
#     'viewport': {'northeast': {'lat': -16.4860598697085,
#       'lng': -151.7393355697085},
#      'southwest': {'lat': -16.4887578302915, 'lng': -151.7420335302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Bora Vaite Lodge',
#    'photos': [{'height': 1335,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114181831206117554023">Tahitiguide Tahitiguide</a>'],
#      'photo_reference': 'Aap_uEDV5KvlhDPbEMso1edBwV3Oinx4uPqMuUIkyTsW1cwELmlxWwB3Us4Sv1G97_2-rd6mq3qhnfZZMrw540XFWL6sppmakw_NVNfXv88QhEyKfkPNq-SOrKJJydyTPRnfPByuRBkpyLpGtmjwm8gYZJq-i-tGF8Sx2UZ-H7joYeiswmHP',
#      'width': 2000}],
#    'place_id': 'ChIJiXylNj69vXYR0PeqcPepXN8',
#    'plus_code': {'compound_code': 'G765+XM Bora-Bora, French Polynesia',
#     'global_code': '53MCG765+XM'},
#    'rating': 5,
#    'reference': 'ChIJiXylNj69vXYR0PeqcPepXN8',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 7,
#    'vicinity': 'French Polynesia'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -16.4875962, 'lng': -151.7407595},
#     'viewport': {'northeast': {'lat': -16.4860598697085,
#       'lng': -151.7393355697085},
#      'southwest': {'lat': -16.4887578302915, 'lng': -151.7420335302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Fare Hibiscus, Bungalow 14',
#    'place_id': 'ChIJy8HXwa-9vXYRjC1Ml6_ZoDA',
#    'plus_code': {'compound_code': 'G765+XM Bora-Bora, French Polynesia',
#     'global_code': '53MCG765+XM'},
#    'reference': 'ChIJy8HXwa-9vXYRjC1Ml6_ZoDA',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': 'Bora-Bora'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -16.4680483, 'lng': -151.753567},
#     'viewport': {'northeast': {'lat': -16.4667179197085,
#       'lng': -151.7522263697085},
#      'southwest': {'lat': -16.4694158802915, 'lng': -151.7549243302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'BoraFareLodge',
#    'photos': [{'height': 640,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101934594501516663560">Maeva Tching</a>'],
#      'photo_reference': 'Aap_uEDDSoIhQc_-7tncuXgTwDiNKflcm1iv9yWPFR2D4ipy3B8Svf89e99QBnPPoYreA8DXQ78w70n80mSxB3NR8KjheYrsEzI4ACNQ-CxG76J8_Q0YGKF8Z7V2PQXvmKxGvyVstmzhLjRDXQYoQeapWlAjX4zfPk23bC_P9UMcCGuKfkQm',
#      'width': 480}],
#    'place_id': 'ChIJgUBUe0m8vXYRb9lwcWpTLio',
#    'plus_code': {'compound_code': 'G6JW+QH Bora-Bora, French Polynesia',
#     'global_code': '53MCG6JW+QH'},
#    'rating': 4.5,
#    'reference': 'ChIJgUBUe0m8vXYRb9lwcWpTLio',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 4,
#    'vicinity': 'Vairupe'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -16.4909651, 'lng': -151.7580277},
#     'viewport': {'northeast': {'lat': -16.4895752697085,
#       'lng': -151.7566737697085},
#      'southwest': {'lat': -16.4922732302915, 'lng': -151.7593717302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': "Bora Bora Holiday's lodge and Villa",
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1668,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114679432552510585871">Bora Bora Holiday&#39;s lodge and Villa</a>'],
#      'photo_reference': 'Aap_uEBp8DnYD0_hByIrBOVImaxkFAlgP-f3Ac2dQRPjQVMC3B80SFCz0l5Q2dndT-TOtNbjE9GlJwnTltAASm3QqyDYCGWR7h9tKv_eIOpxuCsGQWhmJTAfOUdiXtzmYyt5hm7iXqMF9qwwzQw59Gt2rA8CGIGpniK25xjwFsD-iy66iseS',
#      'width': 2500}],
#    'place_id': 'ChIJazKtbTK9vXYRYlbyPNZhpkg',
#    'plus_code': {'compound_code': 'G65R+JQ Bora-Bora, French Polynesia',
#     'global_code': '53MCG65R+JQ'},
#    'rating': 4.9,
#    'reference': 'ChIJazKtbTK9vXYRYlbyPNZhpkg',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 38,
#    'vicinity': 'Faatahi Vaitape BORA BORA'}],
#  'status': 'OK'}

# %%
len(hotels["results"])
# Out:
# 20

# %%
hotels["results"][0]["name"]
# Out:
# 'Bora-Bora Pearl Beach Resort & Spa'
